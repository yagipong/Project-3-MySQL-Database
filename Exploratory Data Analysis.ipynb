# %%
import numpy as np
import pandas as pd
import seaborn as sns

import os, time, math, json
with open('/Users/yawagipong/.secret/tmdb_api.json', 'r') as f:
          login = json.load(f)
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook

FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok = True)
os.listdir(FOLDER)
# Out:
# ['title.ratings.csv.gz',
#  'tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'tmdb_api_results_2001.json',
#  'title_basics.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  '.ipynb_checkpoints',
#  'title.akas.csv.gz']

# %%
tmdb.API_KEY = login['api-key']

# %%
movies_2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
movies_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
movies_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
movies_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
# ...

# %%
movies_years = [movies_2000, movies_2001]
df = pd.concat(movies_years)
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %% [markdown]
# Question 1

# %%
budget_filter = df['budget'] > 0
revenue_filter = df['revenue'] > 0

# %%
df = df.loc[budget_filter | revenue_filter, :]
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 6     tt0119273    0.0  /f5C03doOWiauu37bToKXtpgP5bS.jpg
# 10    tt0120263    0.0  /ynXVuylP8upazjz8lrqb1PEMkdR.jpg
# 11    tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# ...         ...    ...                               ...
# 1231  tt0439449    0.0                               NaN
# 1234  tt0445841    0.0  /lO3XAxV38SC7ZuuNVdy6E6nOZac.jpg
# 1250  tt0867181    0.0                               NaN
# 1252  tt1039952    0.0  /yTGmGjAd0gfpVK0ezoqWgx7AJkp.jpg
# 1265  tt1764172    0.0                               NaN
#
#                                   belongs_to_collection      budget  \
# 1                                                   NaN  10000000.0
# 4                                                   NaN    150000.0
# 6     {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# ...

# %% [markdown]
# 627 movies had at least some valid financial information.

# %% [markdown]
# Question 2

# %%
df['certification'].value_counts()
# Out:
# R        230
# PG-13    131
# PG        35
# NR        17
# G         14
# Name: certification, dtype: int64

# %% [markdown]
# Question 3

# %%
R_cat = df['certification'] == 'R'
PG13_cat = df['certification'] == 'PG-13'
PG_cat = df['certification'] == 'PG'
NR_cat = df['certification'] == 'NR'
G_cat = df['certification'] == 'G'

# %%
R = df.loc[R_cat]
R_rev = R['revenue'].mean()
R_rev
# Out:
# 33066920.278260868

# %%
PG13 = df.loc[PG13_cat]
PG13_rev = PG13['revenue'].mean()
PG13_rev
# Out:
# 99262990.70229007

# %%
PG = df.loc[PG_cat]
PG_rev = PG['revenue'].mean()
PG_rev
# Out:
# 112649587.0

# %%
NR = df.loc[NR_cat]
NR_rev = NR['revenue'].mean()
NR_rev
# Out:
# 8887611.470588235

# %%
G = df.loc[G_cat]
G_rev = G['revenue'].mean()
G_rev
# Out:
# 123746274.92857143

# %% [markdown]
# Question 4

# %%
R_budget = R['budget'].mean()
R_budget
# Out:
# 19660888.913043477

# %%
PG13_budget = PG13['budget'].mean()
PG13_budget
# Out:
# 43153877.30534351

# %%
PG_budget = PG['budget'].mean()
PG_budget
# Out:
# 44964285.97142857

# %%
NR_budget = NR['budget'].mean()
NR_budget
# Out:
# 6302358.470588235

# %%
G_budget = G['budget'].mean()
G_budget
# Out:
# 40857142.85714286

# %%
df = pd.concat(movies_years)
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1292  tt7797670    0.0                               NaN
# 1293  tt7797790    0.0                               NaN
# 1294  tt8665056    0.0                               NaN
# 1295  tt8795764    0.0                               NaN
# 1296  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...

# %%
df.to_csv("Data/tmdb_results_combined.csv.gz",compression='gzip',index=False)
